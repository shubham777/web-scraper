# %%
import bs4
import pandas as pd
import time
import requests
from urllib.request import urlopen as uReq
from urllib.request import Request
from bs4 import BeautifulSoup

# %%
url1= 'https://www.indeed.co.in/jobs?q=receptionist+cum+office+assistant&l=Chandigarh%2C+Chandigarh'
url2= 'https://www.indeed.co.in/jobs?q=account+executive&l=Chandigarh'
url3= 'https://www.indeed.co.in/jobs?q=account+assistant&l=Chandigarh'
url4= 'https://www.indeed.co.in/jobs?q=front+office+executive&l=Chandigarh'
url5= 'https://www.indeed.co.in/jobs?q=front+office+associate&l=Chandigarh'
url6= 'https://www.indeed.co.in/jobs?q=computer+operator&l=Chandigarh'
url7= 'https://www.indeed.co.in/jobs?q=data+entry+operator&l=Chandigarh'
url8= 'https://www.indeed.co.in/jobs?q=accountant&l=Chandigarh'



li_of_url= [url1]
# url1,url2,url3,url4,url5,url6,url7

job_title=[]
companies=[]
locations=[]
salaries=[]
summaries=[]
urls=[]
date=[]

# %%
max_results=40   
df1=pd.DataFrame(columns=['Job Title','Company','Location','Salary','Summary','URL','Date Posted'])
    
for url in li_of_url:
    for start in range(0,max_results,10):

        URL = url+'&start='+str(start)

        time.sleep(1)
        #conducting a request of the stated URL above:
        req=Request(URL, headers={'User-Agent': 'Mozilla/5.0'})
        uClient=uReq(req)

        #offloads the content into a variable
        page_html= uClient.read()
        uClient.close()

        #html parsing
        soup= BeautifulSoup(page_html,'lxml')

        for div in soup.find_all(name='div', attrs={'class':'title'}):
            for a in div.find_all(name='a', attrs={'data-tn-element':'jobTitle'}):
                job_title.append(a['title'])


        for div in soup.find_all(name='div', attrs={'class':'row'}):
            company = div.find_all(name='span', attrs={'class':'company'})
            if len(company) > 0:
                for b in company:
                    companies.append(b.text.strip())
            else:
                sec_try = div.find_all(name='span', attrs={'class':'result-link-source'})
                for span in sec_try:
                    companies.append(span.text.strip())

        for div in soup.find_all(name='div', attrs={'class':'row'}):
            c = div.find_all('span',attrs={'class':'location'})
            for span in c:
                locations.append(span.text)

        for div in soup.find_all(name='div', attrs={'class':'row'}): 
             d= div.find_all('div',attrs={'class':'location'})
             for div in d:
                 locations.append(div.text)

        for div in soup.find_all(name='div', attrs={'class':'row'}):
            try:
                salary = div.find('span', {'class':'no-wrap'}).text.strip()
                salaries.append(salary)
            except:
                salary = 'Nothing Found'
                salaries.append(salary)

#         for div in soup.find_all(name='div', attrs={'class':'row'}):
#             for d in div.find_all(name='div', attrs={'class':'summary'}):
#                 summaries.append(d.text.strip())

        for div in soup.find_all(name='div', attrs={'class':'row'}):
            for d in div.find_all('div',attrs={'class':'title'}):
                for a in d.find_all('a'):
                    l=a.get('href')
                    link='https://www.indeed.co.in'+l
                    urls.append(link)


        for div in soup.find_all(name='div', attrs={'class':'row'}): 
            for span in div.find_all(name='span',attrs={'class':'date'}):
                tex=span.text
                date.append(tex)

        for div in soup.find_all(name='div', attrs={'class':'row'}):
            for span in div.find_all(name='span',attrs={'class':'sponsoredGray'}):
                tex=span.text
                date.append(tex)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-bcd69d4c532d> in <module>
#      67             for span in div.find_all(name='span',attrs={'class':'date'}):
#      68                 tex=span.text
# ---> 69                 date.append(tex)
#      70
#      71         for div in soup.find_all(name='div', attrs={'class':'row'}):
#
# AttributeError: 'function' object has no attribute 'append'

# %%
for url in urls:
    
    my_url=url
    #opening up the connection, grabbing the url
    req=Request(my_url, headers={'User-Agent': 'Chrome/70.0.3538.77'})

    uClient=uReq(req)

    #offloads the content into a variable
    page_html= uClient.read()
    uClient.close()

    #html parsing
    page_soup= BeautifulSoup(page_html,"lxml")
#     div= page_soup.find_all('div',attrs={'class':'jobsearch-jobDescriptionText'})
#     for x in div:
#         TEX= x.find_all('p').text   
#         summaries.append(TEX)
    posting = page_soup.find(name='div', attrs={'class': "jobsearch-JobComponent"}).get_text()
    summaries.append(posting)

# %%
summaries[0]
# Out:
# "Receptionist cum Office AssistantGMEPL Group-₹8,000 - ₹12,000 a monthChandigarh, Chandigarh₹8,000 - ₹12,000 a monthJob SummaryWe have urgent opening of Receptionist cum Office Assistant . Fresher can also apply .**We are looking for a Receptionist to manage our front desk on a daily basis and to perform a variety of administrative and clerical tasks.Candidate should have excellent communication skills .Thanks HR TeamJob Type: Full-timeSalary: ₹8,000.00 to ₹12,000.00 /monthExperience:work: 1 year (Preferred)total work: 1 year (Preferred)Front Office: 1 year (Preferred)Education:Bachelor's (Preferred) - 5 days ago - save job - Is there a problem with this job?Responsive employerResponded to 75% or more applications in the past 30 days, typically within 1 day.Apply NowApply NowSave this job"

# %%
df1['Job Title']=job_title
df1['Company']=companies
df1['Location']=locations
df1['Salary']=salaries
df1['Summary']=summaries
df1['URL']=urls
df1['Date Posted']=date

# %%
df1.drop_duplicates()
# Out:
#                                             Job Title  \
# 0                   Receptionist cum Office Assistant
# 1                   Receptionist cum Office Assistant
# 2                   Receptionist cum Office Assistant
# 3                   Receptionist cum Office Assistant
# 4   Fresher Receptionist cum Office Assistant (Fem...
# 5                   Receptionist cum Office Assistant
# 6                   Receptionist cum Office Assistant
# 7                   RECEPTIONIST CUM OFFICE ASSISTANT
# 8                 Receptionist cum Office Coordinator
# 9                   Receptionist cum Office Assistant
# 10                                   Office Assistant
# 13                  Receptionist cum Office Assistant
# 14    Receptionist cum Office Assistant (Female Only)
# 15                  Receptionist cum Office Assistant
#
#                                         Company  \
# 0                                   GMEPL Group
# 1           Smart choice immigration consultant
# 2   Radha Krishna Tent Palace & Wedding Planner
# 3                   Orane International Pvt Ltd
# 4                      Print Factory Chandigarh
# 5                Red Bean Hospitality Pvt. Ltd.
# 6                 GK Software Solutions pvt ltd
# 7                              Wize Enterprises
# 8                                    2much Jobs
# 9             Shaping Careers Education Society
# 10                           GEMINI ADVERTISING
# 13                           maxim merry school
# 14                           Tricity Placements
# 15                           Tricity Placements
#
#                             Location                        Salary  \
# 0             Chandigarh, Chandigarh      ₹8,000 - ₹12,000 a month
# 1   Sector 20 Chandigarh, Chandigarh      ₹8,000 - ₹15,000 a month
# 2             Chandigarh, Chandigarh                 Nothing Found
# 3             Chandigarh, Chandigarh     ₹10,000 - ₹12,000 a month
# 4             Chandigarh, Chandigarh     ₹10,000 - ₹15,000 a month
# 5                     Mohali, Punjab                 Nothing Found
# 6             Chandigarh, Chandigarh                 Nothing Found
# 7             Chandigarh, Chandigarh               ₹10,000 a month
# 8             Chandigarh, Chandigarh  ₹2,50,000 - ₹3,00,000 a year
# 9                 Panchkula, Haryana     ₹10,000 - ₹12,000 a month
# 10      Mohali Sas Nagar, Chandigarh                 Nothing Found
# 13                    Kharar, Punjab     ₹10,300 - ₹15,100 a month
# 14                    Mohali, Punjab     ₹10,000 - ₹12,000 a month
# 15                  Zirakpur, Punjab                 Nothing Found
#
#                                               Summary  \
# 0   Receptionist cum Office AssistantGMEPL Group-₹...
# 1   Receptionist cum Office AssistantSmart choice ...
# 2   Receptionist cum Office AssistantRadha Krishna...
# 3   Receptionist cum Office AssistantOrane Interna...
# 4   Fresher Receptionist cum Office Assistant (Fem...
# 5   Receptionist cum Office AssistantRed Bean Hosp...
# 6   Receptionist cum Office AssistantGK Software S...
# 7   RECEPTIONIST CUM OFFICE ASSISTANTWize Enterpri...
# 8   Receptionist cum Office Coordinator2much Jobs-...
# 9   Receptionist cum Office AssistantShaping Caree...
# 10  Office AssistantGEMINI ADVERTISING-Mohali Sas ...
# 13  Receptionist cum Office Assistantmaxim merry s...
# 14  Receptionist cum Office Assistant (Female Only...
# 15  Receptionist cum Office AssistantTricity Place...
#
#                                                   URL   Date Posted
# 0   https://www.indeed.co.in/company/Trip-for-me/j...    5 days ago
# 1   https://www.indeed.co.in/company/Go-viza-Educa...     1 day ago
# 2   https://www.indeed.co.in/company/Radha-Krishna...  30+ days ago
# 3   https://www.indeed.co.in/company/Orane-Interna...    5 days ago
# 4   https://www.indeed.co.in/company/Print-Factory...  30+ days ago
# 5   https://www.indeed.co.in/company/Red-Bean-Hosp...    4 days ago
# 6   https://www.indeed.co.in/company/GK-Software-S...    3 days ago
# 7   https://www.indeed.co.in/rc/clk?jk=cc0aee135f7...  30+ days ago
# 8   https://www.indeed.co.in/rc/clk?jk=b1eda5de782...   16 days ago
# 9   https://www.indeed.co.in/company/SHAPING-CAREE...   25 days ago
# 10  https://www.indeed.co.in/company/Gemini-Advert...    4 days ago
# 13  https://www.indeed.co.in/company/maxim-merry-s...  30+ days ago
# 14  https://www.indeed.co.in/company/Tricity-place...   15 days ago
# 15  https://www.indeed.co.in/company/Tricity-place...   27 days ago

# %%
len(date)
# Out:
# 16

# %%
len(summaries)
# Out:
# 16

# %%
df1=df1[df1.Company!='2much Jobs']

# %%
df1
# Out:
#                                             Job Title  \
# 0                   Receptionist cum Office Assistant
# 1                   Receptionist cum Office Assistant
# 2                   Receptionist cum Office Assistant
# 3                   Receptionist cum Office Assistant
# 4   Fresher Receptionist cum Office Assistant (Fem...
# 5                   Receptionist cum Office Assistant
# 6                   Receptionist cum Office Assistant
# 7                   RECEPTIONIST CUM OFFICE ASSISTANT
# 9                   Receptionist cum Office Assistant
# 10                                   Office Assistant
# 12  Fresher Receptionist cum Office Assistant (Fem...
# 13                  Receptionist cum Office Assistant
# 14    Receptionist cum Office Assistant (Female Only)
# 15                  Receptionist cum Office Assistant
#
#                                         Company  \
# 0                                   GMEPL Group
# 1           Smart choice immigration consultant
# 2   Radha Krishna Tent Palace & Wedding Planner
# 3                   Orane International Pvt Ltd
# 4                      Print Factory Chandigarh
# 5                Red Bean Hospitality Pvt. Ltd.
# 6                 GK Software Solutions pvt ltd
# 7                              Wize Enterprises
# 9             Shaping Careers Education Society
# 10                           GEMINI ADVERTISING
# 12                     Print Factory Chandigarh
# 13                           maxim merry school
# 14                           Tricity Placements
# 15                           Tricity Placements
#
#                             Location                     Salary  \
# 0             Chandigarh, Chandigarh   ₹8,000 - ₹12,000 a month
# 1   Sector 20 Chandigarh, Chandigarh   ₹8,000 - ₹15,000 a month
# 2             Chandigarh, Chandigarh              Nothing Found
# 3             Chandigarh, Chandigarh  ₹10,000 - ₹12,000 a month
# 4             Chandigarh, Chandigarh  ₹10,000 - ₹15,000 a month
# 5                     Mohali, Punjab              Nothing Found
# 6             Chandigarh, Chandigarh              Nothing Found
# 7             Chandigarh, Chandigarh            ₹10,000 a month
# 9                 Panchkula, Haryana  ₹10,000 - ₹12,000 a month
# 10      Mohali Sas Nagar, Chandigarh              Nothing Found
# 12            Chandigarh, Chandigarh  ₹10,000 - ₹15,000 a month
# 13                    Kharar, Punjab  ₹10,300 - ₹15,100 a month
# 14                    Mohali, Punjab  ₹10,000 - ₹12,000 a month
# 15                  Zirakpur, Punjab              Nothing Found
#
#                                               Summary  \
# 0   Receptionist cum Office AssistantGMEPL Group-₹...
# 1   Receptionist cum Office AssistantSmart choice ...
# 2   Receptionist cum Office AssistantRadha Krishna...
# 3   Receptionist cum Office AssistantOrane Interna...
# 4   Fresher Receptionist cum Office Assistant (Fem...
# 5   Receptionist cum Office AssistantRed Bean Hosp...
# 6   Receptionist cum Office AssistantGK Software S...
# 7   RECEPTIONIST CUM OFFICE ASSISTANTWize Enterpri...
# 9   Receptionist cum Office AssistantShaping Caree...
# 10  Office AssistantGEMINI ADVERTISING-Mohali Sas ...
# 12  Fresher Receptionist cum Office Assistant (Fem...
# 13  Receptionist cum Office Assistantmaxim merry s...
# 14  Receptionist cum Office Assistant (Female Only...
# 15  Receptionist cum Office AssistantTricity Place...
#
#                                                   URL   Date Posted
# 0   https://www.indeed.co.in/company/Trip-for-me/j...    5 days ago
# 1   https://www.indeed.co.in/company/Go-viza-Educa...     1 day ago
# 2   https://www.indeed.co.in/company/Radha-Krishna...  30+ days ago
# 3   https://www.indeed.co.in/company/Orane-Interna...    5 days ago
# 4   https://www.indeed.co.in/company/Print-Factory...  30+ days ago
# 5   https://www.indeed.co.in/company/Red-Bean-Hosp...    4 days ago
# 6   https://www.indeed.co.in/company/GK-Software-S...    3 days ago
# 7   https://www.indeed.co.in/rc/clk?jk=cc0aee135f7...  30+ days ago
# 9   https://www.indeed.co.in/company/SHAPING-CAREE...   25 days ago
# 10  https://www.indeed.co.in/company/Gemini-Advert...    4 days ago
# 12  https://www.indeed.co.in/company/Print-Factory...  30+ days ago
# 13  https://www.indeed.co.in/company/maxim-merry-s...  30+ days ago
# 14  https://www.indeed.co.in/company/Tricity-place...   15 days ago
# 15  https://www.indeed.co.in/company/Tricity-place...   27 days ago

# %%
df1=df1[df1.Company!='GK Software Solutions pvt ltd']
df1=df1[df1.Company!='Edulink Info Services']
# df1[df1.Company!='Kapasa Jobs']
# df1[df1.Company!='Bhatia Consultancy Services']
# df1[df1.Company!='Nexgen Unisoft Industries pvt ltd']

# %%
import re

def date(dat):
    return re.findall(r'\d+',dat)


df1['Date']=df1['Date Posted'].apply(date)

df1['Date'] = df1['Date'].apply(pd.to_numeric) 

df1=df1[df1['Date']<=15]
df1

# df2=df1[Date Posted]
# Out:
#                                           Job Title  \
# 0                 Receptionist cum Office Assistant
# 1                 Receptionist cum Office Assistant
# 3                 Receptionist cum Office Assistant
# 5                 Receptionist cum Office Assistant
# 6                 Receptionist cum Office Assistant
# 10                                 Office Assistant
# 14  Receptionist cum Office Assistant (Female Only)
#
#                                 Company                          Location  \
# 0                           GMEPL Group            Chandigarh, Chandigarh
# 1   Smart choice immigration consultant  Sector 20 Chandigarh, Chandigarh
# 3           Orane International Pvt Ltd            Chandigarh, Chandigarh
# 5        Red Bean Hospitality Pvt. Ltd.                    Mohali, Punjab
# 6         GK Software Solutions pvt ltd            Chandigarh, Chandigarh
# 10                   GEMINI ADVERTISING      Mohali Sas Nagar, Chandigarh
# 14                   Tricity Placements                    Mohali, Punjab
#
#                        Salary  \
# 0    ₹8,000 - ₹12,000 a month
# 1    ₹8,000 - ₹15,000 a month
# 3   ₹10,000 - ₹12,000 a month
# 5               Nothing Found
# 6               Nothing Found
# 10              Nothing Found
# 14  ₹10,000 - ₹12,000 a month
#
#                                               Summary  \
# 0   Receptionist cum Office AssistantGMEPL Group-₹...
# 1   Receptionist cum Office AssistantSmart choice ...
# 3   Receptionist cum Office AssistantOrane Interna...
# 5   Receptionist cum Office AssistantRed Bean Hosp...
# 6   Receptionist cum Office AssistantGK Software S...
# 10  Office AssistantGEMINI ADVERTISING-Mohali Sas ...
# 14  Receptionist cum Office Assistant (Female Only...
#
#                                                   URL  Date Posted  Date
# 0   https://www.indeed.co.in/company/Trip-for-me/j...   5 days ago   [5]
# 1   https://www.indeed.co.in/company/Go-viza-Educa...    1 day ago   [1]
# 3   https://www.indeed.co.in/company/Orane-Interna...   5 days ago   [5]
# 5   https://www.indeed.co.in/company/Red-Bean-Hosp...   4 days ago   [4]
# 6   https://www.indeed.co.in/company/GK-Software-S...   3 days ago   [3]
# 10  https://www.indeed.co.in/company/Gemini-Advert...   4 days ago   [4]
# 14  https://www.indeed.co.in/company/Tricity-place...  15 days ago  [15]

# %% [markdown]
# ###
